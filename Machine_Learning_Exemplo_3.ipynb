# %% [markdown]
# <a href="https://colab.research.google.com/github/Stanniack/MachineLearningExamples/blob/main/Machine_Learning_Exemplo_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/guilhermesilveira/1b7d5475863c15f484ac495bd70975cf/raw/16aff7a0aee67e7c100a2a48b676a2d2d142f646/projects.csv"
dados = pd.read_csv(url)

# %% [markdown]
# inglês -> Português

# %%
troca_colunas = {
    "unfinished" : "nfinalizado",
    "expected_hours" : "horas_conclusao",
    "price" : "preco"
}

dados = dados.rename(columns = troca_colunas)

dados.head()
# Out:
#    nfinalizado  horas_conclusao  preco
# 0            1               26    192
# 1            1               88   9015
# 2            1               89   2577
# 3            1               42    275
# 4            1               39    170

# %% [markdown]
# **Inverter 0 e 1**
#
# 0 **->** Não Finalizado
#
# 1 **->** Finalizado

# %%
inverter = {
    1 : 0,
    0 : 1
}

dados['finalizado'] = dados.nfinalizado.map(inverter)

# %%
dados.head()
# Out:
#    nfinalizado  horas_conclusao  preco  finalizado
# 0            1               26    192           0
# 1            1               88   9015           0
# 2            1               89   2577           0
# 3            1               42    275           0
# 4            1               39    170           0

# %%
dados.tail()
# Out:
#       nfinalizado  horas_conclusao  preco  finalizado
# 2152            0               80   7518           1
# 2153            1               52   1332           0
# 2154            0               40    473           1
# 2155            0               75   5324           1
# 2156            1               37    377           0

# %% [markdown]
# Plot de gráfico X = preço , Y = horas para conclusão

# %%
import seaborn as sns

sns.scatterplot(x = "horas_conclusao", y = "preco", data = dados)

# %% [markdown]
# **Colorir a variável "finalizado"**

# %%
#hue = definir colaração para variável
sns.scatterplot(x = "horas_conclusao", y = "preco", hue = "finalizado", data = dados)

# %% [markdown]
# **Dividindo gráfico de acordo com a variável**

# %%
sns.relplot(x = "horas_conclusao", y = "preco", hue="finalizado", col = "finalizado", data = dados)
